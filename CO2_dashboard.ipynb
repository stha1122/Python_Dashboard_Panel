# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='ae00e710-1ec8-4da2-bfbe-006be1572994'>
#   <div id="aa88a42b-ecd6-4e34-8c27-cb6c2c793bf4" data-root-id="ae00e710-1ec8-4da2-bfbe-006be1572994" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b9bf751e-9716-49bf-b1bf-de02c1bc1548":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"ae00e710-1ec8-4da2-bfbe-006be1572994"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d032d5db-3216-4f11-a00f-9838ac365dd4","attributes":{"plot_id":"ae00e710-1ec8-4da2-bfbe-006be1572994","comm_id":"e40ff70c9491405cb9ccada872fb751b","client_comm_id":"66a8b7dbce34400db10267d5a2f762ff"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"b9bf751e-9716-49bf-b1bf-de02c1bc1548","roots":{"ae00e710-1ec8-4da2-bfbe-006be1572994":"aa88a42b-ecd6-4e34-8c27-cb6c2c793bf4"},"root_ids":["ae00e710-1ec8-4da2-bfbe-006be1572994"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df= pd.read_csv('https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv')

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1850      AFG   3752993.0           NaN         NaN
# 1      Afghanistan  1851      AFG   3767956.0           NaN         NaN
# 2      Afghanistan  1852      AFG   3783940.0           NaN         NaN
# 3      Afghanistan  1853      AFG   3800954.0           NaN         NaN
# 4      Afghanistan  1854      AFG   3818038.0           NaN         NaN
# ...            ...   ...      ...         ...           ...         ...
# 50593     Zimbabwe  2017      ZWE  14751101.0  2.194784e+10       0.469
# 50594     Zimbabwe  2018      ZWE  15052191.0  2.271535e+10       0.558
# 50595     Zimbabwe  2019      ZWE  15354606.0           NaN       0.570
# 50596     Zimbabwe  2020      ZWE  15669663.0           NaN       0.570
# 50597     Zimbabwe  2021      ZWE  15993525.0           NaN       0.570
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                        NaN     NaN             NaN              NaN  ...
# 1                        NaN     NaN             NaN              NaN  ...
# 2                        NaN     NaN             NaN              NaN  ...
# 3                        NaN     NaN             NaN              NaN  ...
# 4                        NaN     NaN             NaN              NaN  ...
# ...                      ...     ...             ...              ...  ...
# 50593                  0.032   9.596          -0.937           -8.899  ...
# 50594                  0.037  11.795           2.199           22.920  ...
# 50595                  0.037  11.115          -0.681           -5.772  ...
# 50596                  0.036  10.608          -0.507           -4.559  ...
# 50597                  0.036  11.296           0.688            6.488  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                 0.165
# 2                         NaN                                 0.164
# 3                         NaN                                 0.164
# 4                         NaN                                 0.163
# ...                       ...                                   ...
# 50593                     NaN                                 0.114
# 50594                     NaN                                 0.114
# 50595                     NaN                                 0.113
# 50596                     NaN                                 0.112
# 50597                     NaN                                 0.111
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 50593                        0.001                        0.001
# 50594                        0.001                        0.001
# 50595                        0.001                        0.001
# 50596                        0.001                        0.001
# 50597                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                            0.000                          0.0        NaN
# 2                            0.000                          0.0        NaN
# 3                            0.000                          0.0        NaN
# 4                            0.000                          0.0        NaN
# ...                            ...                          ...        ...
# 50593                        0.002                          0.0     115.59
# 50594                        0.002                          0.0     118.22
# 50595                        0.002                          0.0     117.96
# 50596                        0.002                          0.0        NaN
# 50597                        0.002                          0.0        NaN
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 50593                     28.30      0.910            9.486
# 50594                     30.83      0.771            6.537
# 50595                     30.53      0.978            8.795
# 50596                       NaN      1.006            9.481
# 50597                       NaN        NaN              NaN
#
# [50598 rows x 79 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp', 'cement_co2',
#        'cement_co2_per_capita', 'co2', 'co2_growth_abs', 'co2_growth_prct',
#        'co2_including_luc', 'co2_including_luc_growth_abs',
#        'co2_including_luc_growth_prct', 'co2_including_luc_per_capita',
#        'co2_including_luc_per_gdp', 'co2_including_luc_per_unit_energy',
#        'co2_per_capita', 'co2_per_gdp', 'co2_per_unit_energy', 'coal_co2',
#        'coal_co2_per_capita', 'consumption_co2', 'consumption_co2_per_capita',
#        'consumption_co2_per_gdp', 'cumulative_cement_co2', 'cumulative_co2',
#        'cumulative_co2_including_luc', 'cumulative_coal_co2',
#        'cumulative_flaring_co2', 'cumulative_gas_co2', 'cumulative_luc_co2',
#        'cumulative_oil_co2', 'cumulative_other_co2', 'energy_per_capita',
#        'energy_per_gdp', 'flaring_co2', 'flaring_co2_per_capita', 'gas_co2',
#        'gas_co2_per_capita', 'ghg_excluding_lucf_per_capita', 'ghg_per_capita',
#        'land_use_change_co2', 'land_use_change_co2_per_capita', 'methane',
#        'methane_per_capita', 'nitrous_oxide', 'nitrous_oxide_per_capita',
#        'oil_co2', 'oil_co2_per_capita', 'other_co2_per_capita',
#        'other_industry_co2', 'primary_energy_consumption',
#        'share_global_cement_co2', 'share_global_co2',
#        'share_global_co2_including_luc', 'share_global_coal_co2',
#        'share_global_cumulative_cement_co2', 'share_global_cumulative_co2',
#        'share_global_cumulative_co2_including_luc',
#        'share_global_cumulative_coal_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_gas_co2', 'share_global_cumulative_luc_co2',
#        'share_global_cumulative_oil_co2', 'share_global_cumulative_other_co2',
#        'share_global_flaring_co2', 'share_global_gas_co2',
#        'share_global_luc_co2', 'share_global_oil_co2',
#        'share_global_other_co2', 'share_of_temperature_change_from_ghg',
#        'temperature_change_from_ch4', 'temperature_change_from_co2',
#        'temperature_change_from_ghg', 'temperature_change_from_n2o',
#        'total_ghg', 'total_ghg_excluding_lucf', 'trade_co2',
#        'trade_co2_share'],
#       dtype='object')

# %% [markdown]
# (0) Some minor data preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita']=np.where(df['population']!=0,df['gdp']/df['population'],0)

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# (1) CO2 emission over time by continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider',start=1750,end=2020,step=5,value=1850)
year_slider
# Out:
# IntSlider(end=2020, name='Year slider', start=1750, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2=pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['co2','co2_per_capita',],
    button_type='success'
)

# %%
continents=['World','Asia','Oceania','Europe','Africa','North America','South America','Antarctica']

# %%
co2_pipeline=(
    idf[
    (idf.year <= year_slider) &
    (idf.country.isin(continents))
    ]
    .groupby(['country','year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_plot=co2_pipeline.hvplot(x='year',by='country',y=yaxis_co2,line_width=2,title="CO2 emission by continent")
co2_plot
# Out:
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='aad6c57f-bab7-44a2-815f-9f37c61933c0'>
#   <div id="bb7252d4-7f72-42e9-84d3-c22fe4ad3e38" data-root-id="aad6c57f-bab7-44a2-815f-9f37c61933c0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a19620e4-1f37-4782-bafe-842ddeab55f8":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"aad6c57f-bab7-44a2-815f-9f37c61933c0","attributes":{"name":"Row06772","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"de30ac90-07cf-4055-a738-e7317299d1ff","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"45058f14-e2be-4f7f-adf5-95a80dfef9e3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5f6ad91f-eb9a-435c-ae53-49777b10488b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3cbe1645-3375-42ec-b343-e1d81b8ad02b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"68f18c27-b50f-495a-99d1-17b00e167ee5","attributes":{"name":"Column06769","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"de30ac90-07cf-4055-a738-e7317299d1ff"},{"id":"45058f14-e2be-4f7f-adf5-95a80dfef9e3"},{"id":"5f6ad91f-eb9a-435c-ae53-49777b10488b"},{"id":"3cbe1645-3375-42ec-b343-e1d81b8ad02b"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"027785bf-94a8-44f8-82dc-6307e519b88e","attributes":{"name":"Column06752","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"de30ac90-07cf-4055-a738-e7317299d1ff"},{"id":"45058f14-e2be-4f7f-adf5-95a80dfef9e3"},{"id":"5f6ad91f-eb9a-435c-ae53-49777b10488b"},{"id":"3cbe1645-3375-42ec-b343-e1d81b8ad02b"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"9f0343b8-d49f-4700-b4a4-792303b04745","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"de30ac90-07cf-4055-a738-e7317299d1ff"},{"id":"5f6ad91f-eb9a-435c-ae53-49777b10488b"},{"id":"3cbe1645-3375-42ec-b343-e1d81b8ad02b"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":1845,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"7d6b0005-bfd9-428d-9190-0052f994f165","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"de30ac90-07cf-4055-a738-e7317299d1ff"},{"type":"object","name":"ImportedStyleSheet","id":"b515b915-9996-4b60-bce0-84a4857e0253","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/button.css"}},{"id":"5f6ad91f-eb9a-435c-ae53-49777b10488b"},{"id":"3cbe1645-3375-42ec-b343-e1d81b8ad02b"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"Figure","id":"ff7f9faa-b263-4eb4-b618-ddb5b9b41a3d","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"91e8e964-cb5e-4a85-a756-4ad3be08e240","attributes":{"tags":[[["year","year",null]],[]],"start":1750.0,"end":1845.0,"reset_start":1750.0,"reset_end":1845.0}},"y_range":{"type":"object","name":"Range1d","id":"0716c2c4-ec4a-45e4-a2be-fdb429cbd792","attributes":{"tags":[[["c ...

# %% [markdown]
# (2) Table-CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator,pagination='remote',page_size=10,sizing_mode='stretch_width')
co2_table
# Out:
# <div id='9427ee61-f3ff-4b8a-a259-1a54e2476d5e'>
#   <div id="a9d05c49-474d-41de-b0cc-b45356fa04a3" data-root-id="9427ee61-f3ff-4b8a-a259-1a54e2476d5e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ee9ea1c3-0efb-48c1-b670-6c3171b44cf6":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"9427ee61-f3ff-4b8a-a259-1a54e2476d5e","attributes":{"name":"Row10737","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a790eb49-0568-47a7-9ca0-0e1b905ffd5c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9c705073-868e-467a-83f4-459696587698","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1bd15d54-1ebf-41ce-84b3-71719170c570","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"24620f53-e092-49ae-9c80-bf86e22a0e5f","attributes":{"name":"Column10734","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa"},{"id":"a790eb49-0568-47a7-9ca0-0e1b905ffd5c"},{"id":"9c705073-868e-467a-83f4-459696587698"},{"id":"1bd15d54-1ebf-41ce-84b3-71719170c570"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"3945dd80-f711-40b2-9cb4-abd33b76e6d5","attributes":{"name":"Column10716","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa"},{"id":"a790eb49-0568-47a7-9ca0-0e1b905ffd5c"},{"id":"9c705073-868e-467a-83f4-459696587698"},{"id":"1bd15d54-1ebf-41ce-84b3-71719170c570"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"70eb9b71-fda8-4a83-923d-41faba19d0f5","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa"},{"id":"9c705073-868e-467a-83f4-459696587698"},{"id":"1bd15d54-1ebf-41ce-84b3-71719170c570"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":2000,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"72ad5f48-7fcd-4d17-8f57-7651c663d635","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa"},{"type":"object","name":"ImportedStyleSheet","id":"7702870d-ca46-4508-9348-a7b7e0b8cd54","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/button.css"}},{"id":"9c705073-868e-467a-83f4-459696587698"},{"id":"1bd15d54-1ebf-41ce-84b3-71719170c570"}],"margin":[5,10],"align":"start","labels":["co2","co2_per_capita"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"e2cdd0b6-f26d-49f4-a15e-8294281ed0a7","attributes":{"name":"Column10731","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e1cb35c1-1ff9-45e5-964c-8b1b3a4f8efa"},{"id":"a790eb49-0568-47a7-9ca0-0e1b905ffd5c"},{"id":"9c70507 ...

# %% [markdown]
# (3) CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline=(
    idf[
    (idf.year==year_slider) & 
    (~(idf.country.isin(continents)))
    ]
    .groupby(['country','year','gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='b911489b-1c5b-48a9-b7b9-16fb35931cb1'>
#   <div id="d83f8df7-e3fe-4d44-bef2-b5b78ffe7212" data-root-id="b911489b-1c5b-48a9-b7b9-16fb35931cb1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0ce8437d-4dc5-4519-a0e4-264e7d5d2798":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"b911489b-1c5b-48a9-b7b9-16fb35931cb1","attributes":{"name":"Row13647","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"699c9b98-952d-4c9d-b80d-835cb21b36b0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"40fad389-60b5-44dc-a065-c30f8037d8e3","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"27c00a4e-fcbb-4d3d-8420-49b981424491","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"283e1e17-893c-48e5-b095-175728b541c4","attributes":{"name":"Column13644","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"699c9b98-952d-4c9d-b80d-835cb21b36b0"},{"id":"40fad389-60b5-44dc-a065-c30f8037d8e3"},{"id":"27c00a4e-fcbb-4d3d-8420-49b981424491"},{"id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"88195e48-4be7-4ba9-9506-914900d86e9e","attributes":{"name":"Column13614","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"699c9b98-952d-4c9d-b80d-835cb21b36b0"},{"id":"40fad389-60b5-44dc-a065-c30f8037d8e3"},{"id":"27c00a4e-fcbb-4d3d-8420-49b981424491"},{"id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"a7c06e19-1b29-49ad-87c2-373a86cdb480","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"699c9b98-952d-4c9d-b80d-835cb21b36b0"},{"id":"27c00a4e-fcbb-4d3d-8420-49b981424491"},{"id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":2000,"step":5}}]}},{"type":"object","name":"panel.models.layout.Column","id":"2aab0c14-aa37-4572-9aa4-b94e81a6a643","attributes":{"name":"Column13629","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"699c9b98-952d-4c9d-b80d-835cb21b36b0"},{"id":"40fad389-60b5-44dc-a065-c30f8037d8e3"},{"id":"27c00a4e-fcbb-4d3d-8420-49b981424491"},{"id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"39df917a-1064-4813-b7c7-283f1fe6f94d","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"699c9b98-952d-4c9d-b80d-835cb21b36b0"},{"type":"object","name":"ImportedStyleSheet","id":"ad6e42eb-242b-499b-aace-fa47ba267b15","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/dataframe.css"}},{"id":"27c00a4e-fcbb-4d3d-8420-49b981424491"},{"id":"a06161d5-9c9a-43c8-a8cb-830b30512ff0"}],"margin":[5,10],"align":"start","text":"&lt;table class=&q ...

# %%
co2_vs_gdp_scatterplot=co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita',
                                                              y='co2',by='country',
                                                              size=80,kind='scatter',alpha=0.7,
                                                              legend=False,height=500,width=500)
co2_vs_gdp_scatterplot
# Out:
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='0df9616c-65eb-42cb-bcf0-e3af3eab0144'>
#   <div id="bc528e4a-bf34-4cae-9e65-1420d8fdee50" data-root-id="0df9616c-65eb-42cb-bcf0-e3af3eab0144" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a016d149-f221-45fa-85ce-2af4c8a9a8a8":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"0df9616c-65eb-42cb-bcf0-e3af3eab0144","attributes":{"name":"Row18924","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"927ab7c4-f323-4264-95bd-4cb40a682b38","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"69aae31e-7dd0-49c4-8911-1ff5d37cc46d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"56480045-a346-42af-a684-c221da35ce4b","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"84a0419e-2251-4439-b455-2f48137fb053","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"b80be0d3-8c3d-4bad-9bb4-778af207eb65","attributes":{"name":"Column18921","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"927ab7c4-f323-4264-95bd-4cb40a682b38"},{"id":"69aae31e-7dd0-49c4-8911-1ff5d37cc46d"},{"id":"56480045-a346-42af-a684-c221da35ce4b"},{"id":"84a0419e-2251-4439-b455-2f48137fb053"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"f52cc5e1-c626-4ca1-a74d-5628cc8a6a7b","attributes":{"name":"Column18904","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"927ab7c4-f323-4264-95bd-4cb40a682b38"},{"id":"69aae31e-7dd0-49c4-8911-1ff5d37cc46d"},{"id":"56480045-a346-42af-a684-c221da35ce4b"},{"id":"84a0419e-2251-4439-b455-2f48137fb053"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"933506bd-b9a1-4c17-a242-919260866eae","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"927ab7c4-f323-4264-95bd-4cb40a682b38"},{"id":"56480045-a346-42af-a684-c221da35ce4b"},{"id":"84a0419e-2251-4439-b455-2f48137fb053"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":2000,"step":5}}]}},{"type":"object","name":"Figure","id":"13899dc9-d73f-425e-9b78-cf2a823c0552","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"bfb74e7e-ab03-4f09-a01e-52eaaccf88e6","attributes":{"tags":[[["gdp_per_capita","gdp_per_capita",null]],[]],"start":-5404.3892073484085,"end":59448.28128083249,"reset_start":-5404.3892073484085,"reset_end":59448.28128083249}},"y_range":{"type":"object","name":"Range1d","id":"aa4459d6-3fbe-49a2-acb3-042dedc16773","attributes":{"tags":[[["co2","co2",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-1391.2352,"end":15303.587200000002,"reset_start":-1391.2352,"reset_end":15303.587200000002}},"x_scale":{"type":"object","name":"LinearScale","id":"a55c4ece-af58-4a55-b60b-8b635f04d80c"},"y_scale":{"type":"object","name":"LinearScale","id":"d13cbd7c-6b26-43bd-b1ba-85153d1beb7d"},"title":{"type":"object","name":"Title","id":"a0f0281f-f61e-47c1-88a4-c177a6acc5fa","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"b879362d-1060-4280-b3c5-1af6c6837c5f","attributes":{"data_source":{"type":"object ...

# %% [markdown]
# (4) Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                                                     x='country', 
                                                     y=yaxis_co2_source, 
                                                     title='CO2 source by continent')
co2_source_bar_plot
# Out:
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\util.py:1175: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   return pd.unique(values)
# C:\Users\Swetha\Desktop\CO2\co2_dashboard\path\to\myenv\lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='899f574b-7f6b-453a-b7cd-7b568253146f'>
#   <div id="f28293de-701a-438d-a0c4-dd2c62273b9a" data-root-id="899f574b-7f6b-453a-b7cd-7b568253146f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"465ef83e-e641-49d4-835b-16f4e44df382":{"version":"3.2.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"899f574b-7f6b-453a-b7cd-7b568253146f","attributes":{"name":"Row25352","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"cff970e5-ab11-4b60-863b-05fe946b7e9e","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9c989c3b-f268-4653-99bd-9f71ab921829","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"d9342a08-456d-4ac9-974d-46cb3b212f8f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e29654b8-5ea7-4ada-9a5a-7789f5239106","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"a77b35c8-6b16-4286-9c35-506af5443eb6","attributes":{"name":"Column25349","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cff970e5-ab11-4b60-863b-05fe946b7e9e"},{"id":"9c989c3b-f268-4653-99bd-9f71ab921829"},{"id":"d9342a08-456d-4ac9-974d-46cb3b212f8f"},{"id":"e29654b8-5ea7-4ada-9a5a-7789f5239106"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"65ad816d-b5bc-48ea-9256-bf168da94231","attributes":{"name":"Column25332","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cff970e5-ab11-4b60-863b-05fe946b7e9e"},{"id":"9c989c3b-f268-4653-99bd-9f71ab921829"},{"id":"d9342a08-456d-4ac9-974d-46cb3b212f8f"},{"id":"e29654b8-5ea7-4ada-9a5a-7789f5239106"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"d00076bc-afb6-4626-90e7-193ea3beeede","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cff970e5-ab11-4b60-863b-05fe946b7e9e"},{"id":"d9342a08-456d-4ac9-974d-46cb3b212f8f"},{"id":"e29654b8-5ea7-4ada-9a5a-7789f5239106"}],"margin":[5,10],"align":"start","title":"Year slider","start":1750,"end":2020,"value":2000,"step":5}},{"type":"object","name":"RadioButtonGroup","id":"5e18808e-96fa-4b5f-8112-a92e54f85847","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"cff970e5-ab11-4b60-863b-05fe946b7e9e"},{"type":"object","name":"ImportedStyleSheet","id":"ab154fa9-a8d6-4eb6-a5ef-f12e7cf35dd8","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.2/dist/css/button.css"}},{"id":"d9342a08-456d-4ac9-974d-46cb3b212f8f"},{"id":"e29654b8-5ea7-4ada-9a5a-7789f5239106"}],"margin":[5,10],"align":"start","labels":["coal_co2","oil_co2","gas_co2"],"active":0}}]}},{"type":"object","name":"Figure","id":"4d20a5e3-87f3-4b18-a94c-618071e11146","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"af8f2d35-ac48-4b35-be12-5585cf62e459","attributes":{"tags":[[["country","country",null]],[]],"factors":["Africa","Antarctica","Asia","Europe","North America","Oceania","South America"]}},"y_range":{"type":"object","name":"Range1d","id":"6b9f8d73-45d2-4b00-8b4 ...

# %% [markdown]
# Creating Dashboard

# %%
#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide emissions are the primary driver of global climate change. It’s widely recognised that to avoid the worst impacts of climate change, the world needs to urgently reduce emissions. But, how this responsibility is shared between regions, countries, and individuals has been an endless point of contention in international discussions."), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                           co2_plot.panel(width=700), margin=(0,25)), 
                 co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), 
                 pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
